# %% [markdown]
# 2 Data Types allow for Arithmetic operations: floating point data types and integers

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# Modulo or "Mod" Operator

# %% [markdown]
# Description: Returns the remainder after division

# %%
7/4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %% [markdown]
# The symbol for mod operator is percent symbol or %

# %%
50 % 5
# Out:
# 0

# %%
23 % 2
# Mod 2 if you want to check if the number or variable is even or odd
# Out:
# 1

# %% [markdown]
# Other Arithmetic Operations

# %%
2 ** 8
# To do powers do ** or a double asterisk
# Out:
# 256

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2+10)*(10+3)
# Out:
# 156

# %% [raw]
# In order to do order of operations put as though in a calculator.

# %%
# Testing and reasoning why .1+.2-.3 is not equal to 0.
.1+.2-.3
# Out:
# 5.551115123125783e-17

# %% [markdown]
# This does not equal 0 because floating point numkbers are represented as binary in a computer. Typically, Python allows for 53 bits of precision in a float. As such there is some difference between the real number and the estimate in the computer. Therefore, .1+.2-.3 is not equal to 0 in Python.
